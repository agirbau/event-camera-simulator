# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib ipympl

# %%
noise_pos = np.load('../data/noise_pos_161lux.npy')

print(noise_pos.shape)

# noise_pos = np.reshape(noise_pos, (noise_pos.shape[0] * noise_pos.shape[1], noise_pos.shape[2]))
# ind_n = np.where(noise_pos[:, -2] == 0)
# noise_pos[ind_n, 1] = 1
# noise_pos[ind_n, -2] = 1
# div = np.tile(noise_pos[:, -2], [noise_pos.shape[1], 1])
# noise_pos = noise_pos / div.transpose()

# noise_pos.shape
# Out:
# (50, 50, 72)

# %%
x_dim, y_dim, z_dim = noise_pos.shape
x, y, z = np.meshgrid(np.arange(x_dim),
                      np.arange(y_dim),
                      np.arange(z_dim),
                      indexing='ij')

# Flatten and filter
x = x.flatten()
y = y.flatten()
z = z.flatten()
values = noise_pos.flatten()
mask = values != 0
x, y = x[mask], y[mask]

plt.figure(figsize=(8, 6))
sns.kdeplot(x=x, y=y, fill=True, cmap="viridis", bw_adjust=0.5, thresh=0.05)
plt.xlabel('X')
plt.ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(projection='3d')
ax = fig.add_subplot()

ax.set_xlabel('X')
ax.set_ylabel('Y')
# ax.set_zlabel('Z')


# noise_pos = noise_pos[::5, ::5, ::5]

x_dim, y_dim, z_dim = noise_pos.shape
x, y = np.meshgrid(np.arange(x_dim),
                      np.arange(y_dim),
                      indexing='ij')
x = x.flatten()
y = y.flatten()
# z = z.flatten()
values = noise_pos.flatten()

nonzero_mask = values != 0
x = x[nonzero_mask]
y = y[nonzero_mask]
values = values[nonzero_mask]

scatter = ax.scatter(x, y, c=values, cmap='viridis', marker='o', alpha=0.6)
# fig.colorbar(scatter, ax=ax, label='Value')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
